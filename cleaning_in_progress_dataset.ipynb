# %%
import requests
import pandas as pd


def pull_data_from_db():
    """
    Pulls data from online UCI databases and collates them
    """
    base_data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/'
    # Pulling processed data as it is in the most usable format but still needs to be cleaned (missing data)
    options = [
        'processed.cleveland.data',
        'processed.hungarian.data',
        'processed.switzerland.data',
        'processed.va.data',
    ]
    columns = [
        'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalanch', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'
    ]

    # This chunk parses the online data into float arrays where it can and adds it to all_data together
    all_data = []
    for o in options:
        req = requests.get(base_data_url + o)
        if req.status_code != 200:
            raise requests.exceptions.ConnectionError(f'Data URL {base_data_url + o} invalid. Please check the URL is valid.')
        content = [y.split(',') for y in req.content.decode('utf-8').split('\n') if len(y) > 1]
        for i in range(len(content)):
            for j in range(len(content[i])):
                if content[i][j] == '?':
                    continue
                content[i][j] = float(content[i][j])
        all_data.extend(content)

    # Can use pandas dataframes if we want
    df = pd.DataFrame(all_data, columns=columns)
    return all_data, df


def get_data():
    """
    Primary function. Handles:
    - pulling data from web
    - parsing data into a usable format
    - cleaning data with ML SVM in mind
    - returning a feature: label set
    """
    # Gets data in an array form (all_data) and Pandas DataFrame form (df)
    all_data, df = pull_data_from_db()

# %%
data,df=pull_data_from_db()

# %%
df
# Out:
#       age  sex   cp trestbps chol fbs restecg thalanch exang oldpeak slope ca  \
# 0    63.0  1.0  1.0      145  233   1       2      150     0     2.3     3  0
# 1    67.0  1.0  4.0      160  286   0       2      108     1     1.5     2  3
# 2    67.0  1.0  4.0      120  229   0       2      129     1     2.6     2  2
# 3    37.0  1.0  3.0      130  250   0       0      187     0     3.5     3  0
# 4    41.0  0.0  2.0      130  204   0       2      172     0     1.4     1  0
# ..    ...  ...  ...      ...  ...  ..     ...      ...   ...     ...   ... ..
# 915  54.0  0.0  4.0      127  333   1       1      154     0       0     ?  ?
# 916  62.0  1.0  1.0        ?  139   0       1        ?     ?       ?     ?  ?
# 917  55.0  1.0  4.0      122  223   1       1      100     0       0     ?  ?
# 918  58.0  1.0  4.0        ?  385   1       2        ?     ?       ?     ?  ?
# 919  62.0  1.0  2.0      120  254   0       2       93     1       0     ?  ?
#
#     thal  num
# 0      6  0.0
# 1      3  2.0
# 2      7  1.0
# 3      3  0.0
# 4      3  0.0
# ..   ...  ...
# 915    ?  1.0
# 916    ?  0.0
# 917    6  2.0
# 918    ?  0.0
# 919    ?  1.0
#
# [920 rows x 14 columns]

# %%
df[df.chol!='?'].chol.plot()
# Out:
# <AxesSubplot:>

# %%
df.fbs.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b3d750a2dbcc> in <module>
# ----> 1 df.fbs.plot()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
df[df.fbs!='?'].fbs.plot()

# %%
df.restecg.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e924065c3b1e> in <module>
# ----> 1 df.restecg.plot()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     267     def generate(self):
#     268         self._args_adjust()
# --> 269         self._compute_plot_data()
#     270         self._setup_subplots()
#     271         self._make_plot()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     416         # no non-numeric frames or series allowed
#     417         if is_empty:
# --> 418             raise TypeError("no numeric data to plot")
#     419
#     420         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
df[df.restecg!='?'].restecg.plot()

# %%
df.dtypes

# %%
new_df=df[df.chol!='?'].dropna()

# %%
new_df=df[df.thalanch!='?'].dropna()

# %%
new_df=df[df.exang!='?'].dropna()

# %%
new_df=df[df.trestbps!='?'].dropna()

new_df
# Out:
#       age  sex   cp trestbps chol fbs restecg thalanch exang oldpeak slope ca  \
# 0    63.0  1.0  1.0      145  233   1       2      150     0     2.3     3  0
# 1    67.0  1.0  4.0      160  286   0       2      108     1     1.5     2  3
# 2    67.0  1.0  4.0      120  229   0       2      129     1     2.6     2  2
# 3    37.0  1.0  3.0      130  250   0       0      187     0     3.5     3  0
# 4    41.0  0.0  2.0      130  204   0       2      172     0     1.4     1  0
# ..    ...  ...  ...      ...  ...  ..     ...      ...   ...     ...   ... ..
# 913  62.0  1.0  4.0      158  170   0       1      138     1       0     ?  ?
# 914  46.0  1.0  4.0      134  310   0       0      126     0       0     ?  ?
# 915  54.0  0.0  4.0      127  333   1       1      154     0       0     ?  ?
# 917  55.0  1.0  4.0      122  223   1       1      100     0       0     ?  ?
# 919  62.0  1.0  2.0      120  254   0       2       93     1       0     ?  ?
#
#     thal  num
# 0      6  0.0
# 1      3  2.0
# 2      7  1.0
# 3      3  0.0
# 4      3  0.0
# ..   ...  ...
# 913    ?  1.0
# 914    3  2.0
# 915    ?  1.0
# 917    6  2.0
# 919    ?  1.0
#
# [861 rows x 14 columns]

# %%
new_df[new_df.trestbps>10]
# Out:
#       age  sex   cp trestbps chol fbs restecg thalanch exang oldpeak slope ca  \
# 0    63.0  1.0  1.0      145  233   1       2      150     0     2.3     3  0
# 1    67.0  1.0  4.0      160  286   0       2      108     1     1.5     2  3
# 2    67.0  1.0  4.0      120  229   0       2      129     1     2.6     2  2
# 3    37.0  1.0  3.0      130  250   0       0      187     0     3.5     3  0
# 4    41.0  0.0  2.0      130  204   0       2      172     0     1.4     1  0
# ..    ...  ...  ...      ...  ...  ..     ...      ...   ...     ...   ... ..
# 913  62.0  1.0  4.0      158  170   0       1      138     1       0     ?  ?
# 914  46.0  1.0  4.0      134  310   0       0      126     0       0     ?  ?
# 915  54.0  0.0  4.0      127  333   1       1      154     0       0     ?  ?
# 917  55.0  1.0  4.0      122  223   1       1      100     0       0     ?  ?
# 919  62.0  1.0  2.0      120  254   0       2       93     1       0     ?  ?
#
#     thal  num
# 0      6  0.0
# 1      3  2.0
# 2      7  1.0
# 3      3  0.0
# 4      3  0.0
# ..   ...  ...
# 913    ?  1.0
# 914    3  2.0
# 915    ?  1.0
# 917    6  2.0
# 919    ?  1.0
#
# [860 rows x 14 columns]

# %%
new_df=new_df[new_df.thalanch>60]

# %%
type(new_df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_df=new_df[new_df.chol!='?'].chol.plot()

# %%
new_df[['age','slope']].groupby('slope').mean()

# %%
new_df.drop(columns=['slope','ca','thal'])

# %%
new_df=new_df[new_df.trestbps>50]
new_df.thalanch=new_df.thalanch.astype('float64')
new_df.describe()

# %%
df.to_csv('cleaned_data.csv')
